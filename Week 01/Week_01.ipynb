# %%
# !wget -O imdb.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1vrQ5czMHoO3pEnmofFskymXMkq_u1dPc"
# !unzip imdb.zip
# !pip -q install eli5
# !pip -q install spacy
# !python -m spacy download en

# %% [markdown]
# Тут придется авторизировать запрос к гугл драйву, извините.

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id': '1d1-5FwxK53ePwygNWeG7jhsOWZbi5HOv'})
downloaded.GetContentFile('train_docs.pkl')

downloaded = drive.CreateFile({'id': '1MMOY477t965G0C5DtXeREVp0X85UaNq5'})
downloaded.GetContentFile('test_docs.pkl')

# %% [markdown]
# # Организационное
#
# Страница курса: https://github.com/DanAnastasyev/DeepNLP-Course
#
# Чатик: https://t.me/joinchat/DgDT4RLYhsTh_x6fRvfMjQ
#
# Примерный план:
#
# 1. Введение
# 2. PyTorch, word embeddings
# 3. RNN 1, text classification
# 4. RNN 2, sequence labeling
# 5. RNN 3, text generation, language models
# 6. CNN, text classification
# 7. Machine translation, attention
# 8. Transformers
# 9. Dialogue systems 1, tagging + classification, multi-task learning
# 10. Dialogue systems 2, DSSM
# 11. Transfer learning
# 12. Tensorflow + xla/aot or Meta BiLSTM (?)
#
# ... and something else

# %% [markdown]
# # Классификация текстов
#
# Начнём с самого простого - анализа тональности текста.
#
# Будем классифицировать отзывы с IMDB на положительные/отрицательные.
#
# Датасет взят с http://ai.stanford.edu/~amaas/data/sentiment/

# %%
# !head train.tsv

# %%
import pandas as pd

train_df = pd.read_csv("train.tsv", delimiter="\t")
test_df = pd.read_csv("test.tsv", delimiter="\t")

print('Train size = {}'.format(len(train_df)))
print('Test size = {}'.format(len(test_df)))
# Out:
# Train size = 25000
# Test size = 25000

# %%
train_df.head()
# Out:
#    is_positive                                             review
# 0            0  Dreamgirls, despite its fistful of Tony wins i...
# 1            0  This show comes up with interesting locations ...
# 2            1  I simply love this movie. I also love the Ramo...
# 3            0  Spoilers ahead if you want to call them that.....
# 4            1  My all-time favorite movie! I have seen many m...

# %% [markdown]
# Посмотрите глазами на тексты? Какие есть зацепки, как определить, что это за сентимент?
#
# Самое простое, как всегда - найти ключевые слова.

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love', 'great', 'best', 'wonderful' #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 66.73%

# %% [markdown]
# **Задание** Придумайте хорошие ключевые слова или фразы и наберите хотя бы 71% точности на тесте (и не забудьте посмотреть на код классификации!)

# %% [markdown]
# **Задание** Кому-нибудь нравятся эти `<br /><br />`? Лично мне - нет. Напишите регулярку, которая будет их удалять

# %%
import re

pattern = re.compile("<br /><br />")

print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas
# Spoilers ahead if you want to call them that... I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top... THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort". THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself. THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards... THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone. TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it. Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it. Signing off... Amanda Christmas

# %% [markdown]
# Применим ее:

# %%
train_df['review'] = train_df['review'].apply(lambda text: pattern.subn(' ', text)[0])
test_df['review'] = test_df['review'].apply(lambda text: pattern.subn(' ', text)[0])

# %% [markdown]
# Пора переходить к машинке!
#
# Как будем представлять текст? Проще всего - мешком слов.
#
# Заведём большой-большой словарь - список всех слов в обучающей выборке. Тогда каждое предложение можно представить в виде вектора, в котором будет записано, сколько раз встретилось каждое из возможных слов:
#
# ![bow](https://raw.githubusercontent.com/DanAnastasyev/DeepNLP-Course/master/Week%2001/Images/BOW.png)
#
# Простой и приятный способ сделать это - запихнуть тексты в `CountVectorizer`.
#
# Он имеет такую сигнатуру:
#
# ```python
# CountVectorizer(input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern=r'(?u)\b\w\w+\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class ‘numpy.int64'>)
# ```
#
# Для начала обратим внимание на параметры `lowercase=True` и `max_df=1.0, min_df=1, max_features=None` - они про то, что по умолчанию все слова будут приводиться к нижнему регистру и в словарь попадут все слова, встречавшиеся в текстах.
#
# При желании можно было бы убрать слишком редкие или слишком частотные слова - пока не будем этого делать.
#
# Посмотрим на простом примере, как он будет работать:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

dummy_data = ['The movie was excellent',
              'the movie was awful']

dummy_matrix = vectorizer.fit_transform(dummy_data)

print(dummy_matrix.toarray())
print(vectorizer.get_feature_names())
# Out:
# [[0 1 1 1 1]
#  [1 0 1 1 1]]
# ['awful', 'excellent', 'movie', 'the', 'was']

# %% [markdown]
# *Как именно vectorizer определяет границы слов? Обратите внимание на параметр `token_pattern=r'(?u)\b\w\w+\b'` - как он будет работать?*
#
# Запустим его на реальных данных:

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_df['review'].values)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %% [markdown]
# Посмотрим на слова, попавшие в словарь:

# %%
vectorizer.get_feature_names()
# Out:
# [' !',
#  ' "',
#  ' "a',
#  ' "b',
#  ' "c',
#  ' "d',
#  ' "f',
#  ' "g',
#  ' "h',
#  ' "i',
#  ' "l',
#  ' "m',
#  ' "p',
#  ' "r',
#  ' "s',
#  ' "t',
#  ' "th',
#  ' "the',
#  ' "the ',
#  ' "w',
#  ' &',
#  ' & ',
#  " '",
#  ' (',
#  ' (1',
#  ' (19',
#  ' (a',
#  ' (an',
#  ' (and',
#  ' (and ',
#  ' (b',
#  ' (c',
#  ' (d',
#  ' (e',
#  ' (i',
#  ' (l',
#  ' (m',
#  ' (n',
#  ' (o',
#  ' (p',
#  ' (s',
#  ' (t',
#  ' (th',
#  ' (the',
#  ' (the ',
#  ' (w',
#  ' (wh',
#  ' *',
#  ' ,',
#  ' -',
#  ' - ',
#  ' - a',
#  ' - i',
#  ' - t',
#  ' - th',
#  ' --',
#  ' -- ',
#  ' .',
#  ' . ',
#  ' 1',
#  ' 10',
#  ' 10 ',
#  ' 19',
#  ' 2',
#  ' 2 ',
#  ' 20',
#  ' 200',
#  ' 3',
#  ' 4',
#  ' 5',
#  ' 6',
#  ' 7',
#  ' 8',
#  ' 9',
#  ' a',
#  ' a ',
#  ' a "',
#  ' a b',
#  ' a ba',
#  ' a bad',
#  ' a be',
#  ' a bi',
#  ' a big',
#  ' a bit',
#  ' a bo',
#  ' a br',
#  ' a bu',
#  ' a c',
#  ' a ca',
#  ' a ch',
#  ' a cha',
#  ' a cl',
#  ' a co',
#  ' a com',
#  ' a cou',
#  ' a cr',
#  ' a d',
#  ' a de',
#  ' a di',
#  ' a do',
#  ' a f',
#  ' a fa',
#  ' a fe',
#  ' a few',
#  ' a fi',
#  ' a fil',
#  ' a fu',
#  ' a g',
#  ' a go',
#  ' a goo',
#  ' a gr',
#  ' a gre',
#  ' a h',
#  ' a ha',
#  ' a hi',
#  ' a ho',
#  ' a hu',
#  ' a j',
#  ' a k',
#  ' a l',
#  ' a la',
#  ' a li',
#  ' a lit',
#  ' a lo',
#  ' a lot',
#  ' a m',
#  ' a ma',
#  ' a man',
#  ' a me',
#  ' a mi',
#  ' a mo',
#  ' a mov',
#  ' a mu',
#  ' a n',
#  ' a ne',
#  ' a ni',
#  ' a p',
#  ' a pa',
#  ' a pe',
#  ' a per',
#  ' a pl',
#  ' a po',
#  ' a pr',
#  ' a pre',
#  ' a r',
#  ' a ra',
#  ' a re',
#  ' a rea',
#  ' a ro',
#  ' a s',
#  ' a sc',
#  ' a se',
#  ' a sh',
#  ' a si',
#  ' a so',
#  ' a sp',
#  ' a st',
#  ' a sto',
#  ' a str',
#  ' a su',
#  ' a t',
#  ' a te',
#  ' a th',
#  ' a to',
#  ' a tr',
#  ' a v',
#  ' a ve',
#  ' a ver',
#  ' a w',
#  ' a wa',
#  ' a we',
#  ' a wh',
#  ' a wo',
#  ' a y',
#  ' a yo',
#  ' a you',
#  ' ab',
#  ' abl',
#  ' able',
#  ' able ',
#  ' abo',
#  ' abou',
#  ' about',
#  ' abs',
#  ' abso',
#  ' absol',
#  ' ac',
#  ' acc',
#  ' acce',
#  ' acco',
#  ' acr',
#  ' acro',
#  ' acros',
#  ' act',
#  ' acti',
#  ' actin',
#  ' actio',
#  ' acto',
#  ' actor',
#  ' actr',
#  ' actre',
#  ' actu',
#  ' actua',
#  ' ad',
#  ' ada',
#  ' add',
#  ' adm',
#  ' admi',
#  ' adu',
#  ' adul',
#  ' adult',
#  ' adv',
#  ' adve',
#  ' af',
#  ' aff',
#  ' aft',
#  ' afte',
#  ' after',
#  ' ag',
#  ' aga',
#  ' agai',
#  ' again',
#  ' age',
#  ' ago',
#  ' ai',
#  ' air',
#  ' al',
#  ' ali',
#  ' all',
#  ' all ',
#  ' all a',
#  ' all i',
#  ' all o',
#  ' all t',
#  ' all,',
#  ' all, ',
#  ' all.',
#  ' all. ',
#  ' allo',
#  ' allow',
#  ' alm',
#  ' almo',
#  ' almos',
#  ' alo',
#  ' alon',
#  ' alone',
#  ' along',
#  ' alr',
#  ' alre',
#  ' alrea',
#  ' als',
#  ' also',
#  ' also ',
#  ' alt',
#  ' alth',
#  ' altho',
#  ' alw',
#  ' alwa',
#  ' alway',
#  ' am',
#  ' am ',
#  ' ama',
#  ' amaz',
#  ' amazi',
#  ' ame',
#  ' amer',
#  ' ameri',
#  ' amo',
#  ' an',
#  ' an ',
#  ' an a',
#  ' an ac',
#  ' an e',
#  ' an en',
#  ' an ex',
#  ' an i',
#  ' an in',
#  ' an o',
#  ' an u',
#  ' an un',
#  ' and',
#  ' and ',
#  ' and "',
#  ' and a',
#  ' and b',
#  ' and c',
#  ' and d',
#  ' and e',
#  ' and f',
#  ' and g',
#  ' and h',
#  ' and i',
#  ' and j',
#  ' and k',
#  ' and l',
#  ' and m',
#  ' and n',
#  ' and o',
#  ' and p',
#  ' and r',
#  ' and s',
#  ' and t',
#  ' and u',
#  ' and v',
#  ' and w',
#  ' and y',
#  ' and,',
#  ' and, ',
#  ' ang',
#  ' ani',
#  ' anim',
#  ' anima',
#  ' ann',
#  ' anno',
#  ' annoy',
#  ' ano',
#  ' anot',
#  ' anoth',
#  ' ant',
#  ' any',
#  ' any ',
#  ' any o',
#  ' anyo',
#  ' anyon',
#  ' anyt',
#  ' anyth',
#  ' anyw',
#  ' anywa',
#  ' ap',
#  ' apa',
#  ' apar',
#  ' apart',
#  ' app',
#  ' appa',
#  ' appar',
#  ' appe',
#  ' appea',
#  ' appr',
#  ' appro',
#  ' ar',
#  ' are',
#  ' are ',
#  ' are a',
#  ' are b',
#  ' are c',
#  ' are f',
#  ' are g',
#  ' are i',
#  ' are m',
#  ' are n',
#  ' are o',
#  ' are p',
#  ' are s',
#  ' are t',
#  ' are w',
#  ' arm',
#  ' aro',
#  ' arou',
#  ' aroun',
#  ' arr',
#  ' art',
#  ' arti',
#  ' as',
#  ' as ',
#  ' as a',
#  ' as a ',
#  ' as an',
#  ' as b',
#  ' as c',
#  ' as f',
#  ' as h',
#  ' as he',
#  ' as i',
#  ' as i ',
#  ' as it',
#  ' as m',
#  ' as o',
#  ' as p',
#  ' as s',
#  ' as t',
#  ' as th',
#  ' as w',
#  ' as we',
#  ' ask',
#  ' asp',
#  ' ass',
#  ' at',
#  ' at ',
#  ' at a',
#  ' at a ',
#  ' at al',
#  ' at h',
#  ' at l',
#  ' at le',
#  ' at t',
#  ' at th',
#  ' att',
#  ' atta',
#  ' attac',
#  ' atte',
#  ' attem',
#  ' atten',
#  ' au',
#  ' aud',
#  ' audi',
#  ' audie',
#  ' aut',
#  ' av',
#  ' avo',
#  ' avoi',
#  ' avoid',
#  ' aw',
#  ' awa',
#  ' awar',
#  ' away',
#  ' away ',
#  ' awf',
#  ' awfu',
#  ' awful',
#  ' b',
#  ' ba',
#  ' bab',
#  ' bac',
#  ' back',
#  ' back ',
#  ' bad',
#  ' bad ',
#  ' bad a',
#  ' bad.',
#  ' bal',
#  ' ban',
#  ' bar',
#  ' bas',
#  ' base',
#  ' based',
#  ' basi',
#  ' basic',
#  ' bat',
#  ' batt',
#  ' be',
#  ' be ',
#  ' be a',
#  ' be a ',
#  ' be b',
#  ' be c',
#  ' be d',
#  ' be f',
#  ' be i',
#  ' be m',
#  ' be r',
#  ' be s',
#  ' be t',
#  ' be th',
#  ' bea',
#  ' beat',
#  ' beau',
#  ' beaut',
#  ' bec',
#  ' beca',
#  ' becau',
#  ' beco',
#  ' becom',
#  ' bee',
#  ' been',
#  ' been ',
#  ' bef',
#  ' befo',
#  ' befor',
#  ' beg',
#  ' begi',
#  ' begin',
#  ' beh',
#  ' behi',
#  ' behin',
#  ' bei',
#  ' bein',
#  ' being',
#  ' bel',
#  ' beli',
#  ' belie',
#  ' ben',
#  ' bes',
#  ' best',
#  ' best ',
#  ' bet',
#  ' bett',
#  ' bette',
#  ' betw',
#  ' betwe',
#  ' bi',
#  ' big',
#  ' big ',
#  ' bil',
#  ' bill',
#  ' bit',
#  ' bit ',
#  ' bl',
#  ' bla',
#  ' blac',
#  ' black',
#  ' blo',
#  ' bloo',
#  ' blood',
#  ' bo',
#  ' bod',
#  ' body',
#  ' bon',
#  ' boo',
#  ' book',
#  ' book ',
#  ' bor',
#  ' bori',
#  ' borin',
#  ' bot',
#  ' both',
#  ' both ',
#  ' bou',
#  ' boy',
#  ' boy ',
#  ' br',
#  ' bra',
#  ' bre',
#  ' brea',
#  ' break',
#  ' bri',
#  ' bril',
#  ' brill',
#  ' brin',
#  ' bring',
#  ' brit',
#  ' bro',
#  ' brot',
#  ' broth',
#  ' bru',
#  ' bu',
#  ' bud',
#  ' budg',
#  ' budge',
#  ' bui',
#  ' buil',
#  ' bun',
#  ' bur',
#  ' bus',
#  ' but',
#  ' but ',
#  ' but a',
#  ' but f',
#  ' but h',
#  ' but i',
#  ' but n',
#  ' but o',
#  ' but s',
#  ' but t',
#  ' but w',
#  ' buy',
#  ' by',
#  ' by ',
#  ' by a',
#  ' by a ',
#  ' by h',
#  ' by m',
#  ' by s',
#  ' by t',
#  ' by th',
#  ' c',
#  ' ca',
#  ' cal',
#  ' call',
#  ' calle',
#  ' cam',
#  ' came',
#  ' came ',
#  ' camer',
#  ' camp',
#  ' can',
#  ' can ',
#  ' can b',
#  ' can s',
#  " can'",
#  " can't",
#  ' cann',
#  ' canno',
#  ' cap',
#  ' capt',
#  ' car',
#  ' care',
#  ' care ',
#  ' caree',
#  ' carr',
#  ' cart',
#  ' cas',
#  ' case',
#  ' case ',
#  ' cast',
#  ' cast ',
#  ' cat',
#  ' cau',
#  ' caus',
#  ' ce',
#  ' cel',
#  ' cen',
#  ' cent',
#  ' cer',
#  ' cert',
#  ' certa',
#  ' ch',
#  ' cha',
#  ' chan',
#  ' chanc',
#  ' chang',
#  ' char',
#  ' chara',
#  ' charl',
#  ' charm',
#  ' che',
#  ' chea',
#  ' cheap',
#  ' chec',
#  ' check',
#  ' chee',
#  ' chi',
#  ' chil',
#  ' child',
#  ' cho',
#  ' chr',
#  ' chri',
#  ' chris',
#  ' chu',
#  ' ci',
#  ' cin',
#  ' cine',
#  ' cinem',
#  ' cit',
#  ' city',
#  ' cl',
#  ' cla',
#  ' clas',
#  ' class',
#  ' cle',
#  ' clea',
#  ' clear',
#  ' cli',
#  ' clic',
#  ' clich',
#  ' clo',
#  ' clos',
#  ' close',
#  ' clu',
#  ' co',
#  ' col',
#  ' coll',
#  ' colle',
#  ' colo',
#  ' com',
#  ' come',
#  ' come ',
#  ' comed',
#  ' comes',
#  ' comi',
#  ' comic',
#  ' comin',
#  ' comm',
#  ' comme',
#  ' comp',
#  ' compa',
#  ' compe',
#  ' compl',
#  ' con',
#  ' conc',
#  ' conce',
#  ' conf',
#  ' confu',
#  ' conn',
#  ' cons',
#  ' consi',
#  ' const',
#  ' cont',
#  ' conta',
#  ' conte',
#  ' conti',
#  ' contr',
#  ' conv',
#  ' conve',
#  ' convi',
#  ' coo',
#  ' cool',
#  ' cop',
#  ' cor',
#  ' cos',
#  ' cost',
#  ' cou',
#  ' coul',
#  ' could',
#  ' coun',
#  ' count',
#  ' coup',
#  ' coupl',
#  ' cour',
#  ' cours',
#  ' cov',
#  ' cove',
#  ' cover',
#  ' cr',
#  ' cra',
#  ' crap',
#  ' cre',
#  ' crea',
#  ' creat',
#  ' cred',
#  ' credi',
#  ' cree',
#  ' cri',
#  ' crim',
#  ' crit',
#  ' criti',
#  ' cro',
#  ' cru',
#  ' cu',
#  ' cul',
#  ' cult',
#  ' cur',
#  ' cut',
#  ' d',
#  ' da',
#  ' dam',
#  ' dan',
#  ' danc',
#  ' dance',
#  ' dar',
#  ' dark',
#  ' dark ',
#  ' dau',
#  ' daug',
#  ' daugh',
#  ' dav',
#  ' davi',
#  ' day',
#  ' day ',
#  ' days',
#  ' de',
#  ' dea',
#  ' dead',
#  ' dead ',
#  ' deal',
#  ' deat',
#  ' death',
#  ' dec',
#  ' dece',
#  ' decen',
#  ' deci',
#  ' decid',
#  ' dee',
#  ' deep',
#  ' def',
#  ' defi',
#  ' defin',
#  ' del',
#  ' deli',
#  ' deliv',
#  ' dem',
#  ' den',
#  ' dep',
#  ' des',
#  ' desc',
#  ' dese',
#  ' deser',
#  ' desi',
#  ' desp',
#  ' despi',
#  ' dest',
#  ' det',
#  ' deta',
#  ' dev',
#  ' deve',
#  ' devel',
#  ' di',
#  ' dia',
#  ' dial',
#  ' dialo',
#  ' did',
#  ' did ',
#  ' did n',
#  ' didn',
#  " didn'",
#  ' die',
#  ' dif',
#  ' diff',
#  ' diffe',
#  ' dir',
#  ' dire',
#  ' direc',
#  ' dis',
#  ' disa',
#  ' disap',
#  ' disc',
#  ' disco',
#  ' dist',
#  ' do',
#  ' do ',
#  ' do n',
#  ' do no',
#  ' do t',
#  ' do th',
#  ' do w',
#  ' doc',
#  ' docu',
#  ' docum',
#  ' doe',
#  ' does',
#  ' does ',
#  ' doesn',
#  ' dog',
#  ' doi',
#  ' doin',
#  ' doing',
#  ' don',
#  " don'",
#  " don't",
#  ' done',
#  ' done ',
#  ' doo',
#  ' dou',
#  ' doub',
#  ' dow',
#  ' down',
#  ' down ',
#  ' dr',
#  ' dra',
#  ' dram',
#  ' drama',
#  ' dre',
#  ' drea',
#  ' dream',
#  ' dri',
#  ' driv',
#  ' drive',
#  ' dru',
#  ' du',
#  ' due',
#  ' dum',
#  ' dur',
#  ' duri',
#  ' durin',
#  ' dv',
#  ' dvd',
#  ' dvd ',
#  ' e',
#  ' ea',
#  ' eac',
#  ' each',
#  ' each ',
#  ' ear',
#  ' earl',
#  ' early',
#  ' eart',
#  ' earth',
#  ' eas',
#  ' easi',
#  ' ed',
#  ' edi',
#  ' edit',
#  ' ef',
#  ' eff',
#  ' effe',
#  ' effec',
#  ' effo',
#  ' effor',
#  ' ei',
#  ' eit',
#  ' eith',
#  ' eithe',
#  ' el',
#  ' ele',
#  ' elem',
#  ' eleme',
#  ' els',
#  ' else',
#  ' else ',
#  ' em',
#  ' emb',
#  ' emo',
#  ' emot',
#  ' emoti',
#  ' emp',
#  ' en',
#  ' end',
#  ' end ',
#  ' end o',
#  ' end.',
#  ' endi',
#  ' endin',
#  ' ends',
#  ' eng',
#  ' engl',
#  ' engli',
#  ' enj',
#  ' enjo',
#  ' enjoy',
#  ' eno',
#  ' enou',
#  ' enoug',
#  ' ent',
#  ' ente',
#  ' enter',
#  ' enti',
#  ' entir',
#  ' ep',
#  ' epi',
#  ' epis',
#  ' episo',
#  ' er',
#  ' es',
#  ' esc',
#  ' esca',
#  ' esp',
#  ' espe',
#  ' espec',
#  ' et',
#  ' etc',
#  ' ev',
#  ' eve',
#  ' even',
#  ' even ',
#  ' event',
#  ' ever',
#  ' ever ',
#  ' every',
#  ' evi',
#  ' evil',
#  ' evil ',
#  ' ex',
#  ' exa',
#  ' exac',
#  ' exact',
#  ' exam',
#  ' examp',
#  ' exc',
#  ' exce',
#  ' excel',
#  ' excep',
#  ' exci',
#  ' excit',
#  ' exe',
#  ' exi',
#  ' exis',
#  ' exist',
#  ' exp',
#  ' expe',
#  ' expec',
#  ' exper',
#  ' expl',
#  ' expla',
#  ' explo',
#  ' ext',
#  ' extr',
#  ' extre',
#  ' ey',
#  ' eye',
#  ' eyes',
#  ' f',
#  ' fa',
#  ' fac',
#  ' face',
#  ' face ',
#  ' fact',
#  ' fact ',
#  ' fai',
#  ' fail',
#  ' fair',
#  ' fal',
#  ' fall',
#  ' fam',
#  ' fami',
#  ' famil',
#  ' fan',
#  ' fan ',
#  ' fan o',
#  ' fans',
#  ' fans ',
#  ' fant',
#  ' fanta',
#  ' far',
#  ' far ',
#  ' fas',
#  ' fast',
#  ' fat',
#  ' fath',
#  ' fathe',
#  ' fav',
#  ' favo',
#  ' favor',
#  ' fe',
#  ' fea',
#  ' feat',
#  ' featu',
#  ' fee',
#  ' feel',
#  ' feel ',
#  ' feeli',
#  ' fel',
#  ...]

# %% [markdown]
# Попробуем кого-нибудь таки сконвертировать

# %%
vectorizer.transform([train_df['review'].iloc[3]])
# Out:
# <1x74849 sparse matrix of type '<class 'numpy.int64'>'
# 	with 206 stored elements in Compressed Sparse Row format>

# %% [markdown]
# То, что и хотели - вектор с bow (т.е. bag-of-words) представлением исходного текста.
#
# И чем эта информация может помочь? Ну, всё тем же - какие-то слова носят положительный окрас, какие-то - отрицательный. Большинство вообще нейтральный, да.
#
# ![bow with weights](https://github.com/DanAnastasyev/DeepNLP-Course/raw/master/Week%2001/Images/BOW_weights.png)
#
# Хочется, наверное, подобрать коэффициенты, которые будут определять уровень окраса, да? Подбирать нужно по обучающей выборке, а не как мы перед этим делали.
#
# Например, для выборки
# ```
# 1   The movie was excellent
# 0   the movie was awful
# ```
# легко подобрать коэффициенты на глазок: что-нибудь вроде `+1` для `excellent`,  `-1` для `awful` и по нулям всем остальным.
#
# Построим линейную модель, которая станет этим заниматься. Она будет учиться строить разделяющую гиперплоскость в пространстве bow-векторов.
#
# Проверим, как справится логистическая регрессия с нашей супер-выборкой из пары предложений

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

dummy_data = ['The movie was excellent',
              'the movie was awful']
dummy_labels = [1, 0]

vectorizer = CountVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(dummy_data, dummy_labels)

print(vectorizer.get_feature_names())
print(classifier.coef_)
# Out:
# ['awful', 'excellent', 'movie', 'the', 'was']
# [[-0.40105812  0.40105812  0.          0.          0.        ]]
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# Получилось что надо.
#
# Запустим теперь её на реальных данных.

# %%
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#        ...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
from sklearn.metrics import accuracy_score

def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    
eval_model(model, test_df)
# Out:
# Test accuracy = 86.67%

# %% [markdown]
# Прогресс!
#
# Хочется как-то посмотреть, что заинтересовало классификатор. К счастью, сделать это совсем просто:

# %%
import eli5
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.585
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         refreshing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.411
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderfully
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.355
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         erotic
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.296
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         funniest
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.288
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.282
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         excellent
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.279
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         carrey
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.260
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         superb
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.250
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         surprisingly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.250
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         appreciated
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.219
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flawless
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.192
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         flight
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.187
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vengeance
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.163
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         units
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 86.98%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37568 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.07%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37242 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.152
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dreadful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.159
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         photo
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.200
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mst3k
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.212
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mediocre
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.230
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         alright
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.232
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         save
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">

# %% [markdown]
# Посмотрим на конкретные примеры его работы:

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>16.249</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +16.205
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 97.40%); opacity: 0.80" title="-0.020">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.75%); opacity: 0.81" title="0.040">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.24%); opacity: 0.87" title="0.334">both</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.07%); opacity: 0.81" title="-0.049">an</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 67.10%); opacity: 0.95" title="0.745">entertaining</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.74%); opacity: 0.82" title="0.086">and</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.985">touching</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.01%); opacity: 0.81" title="-0.050">version</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.03%); opacity: 0.81" title="-0.065">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 78.15%); opacity: 0.88" title="0.415">classic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.85%); opacity: 0.85" title="0.223">tale</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 85.95%); opacity: 0.84" title="0.221">also</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.65%); opacity: 0.84" title="0.205">quite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.84%); opacity: 0.85" title="0.270">intelligent</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 86.82%); opacity: 0.84" title="-0.202">not</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.03%); opacity: 0.81" title="-0.065">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> &#x27;</span><span style="background-color: hsl(0, 100.00%, 99.64%); opacity: 0.80" title="-0.001">me</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.62%); opacity: 0.82" title="0.106">tarzan</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 87.35%); opacity: 0.84" title="0.190">you</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.99%); opacity: 0.82" title="0.099">jane</span><span style="opacity: 0.80">&#x27; </span><span style="background-color: hsl(120, 100.00%, 93.60%); opacity: 0.81" title="0.072">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.27%); opacity: 0.80" title="-0.011">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.46%); opacity: 0.80" title="0.002">all</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(120, 100.00%, 90.53%); opacity: 0.83" title="0.126">it</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(120, 100.00%, 96.42%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.02%); opacity: 0.85" title="0.265">famous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.67%); opacity: 0.81" title="0.041">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.03%); opacity: 0.81" title= ...

# %%
print('Positive' if test_df['is_positive'].iloc[0] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[0], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Negative
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.003</b>, score <b>-5.911</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -5.955
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">a </span><span style="background-color: hsl(0, 100.00%, 92.78%); opacity: 0.82" title="-0.184">formulaic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.47%); opacity: 0.80" title="0.041">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.77%); opacity: 0.80" title="0.015">with</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.68%); opacity: 0.80" title="0.002">all</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.91%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.50%); opacity: 0.83" title="-0.314">tired</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 89.99%); opacity: 0.83" title="-0.293">cliches</span><span style="opacity: 0.80">. i </span><span style="background-color: hsl(0, 100.00%, 96.47%); opacity: 0.81" title="-0.066">was</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.39%); opacity: 0.85" title="0.553">shocked</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.75%); opacity: 0.80" title="-0.015">that</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.91%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 70.85%); opacity: 0.93" title="-1.349">horrible</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 83.37%); opacity: 0.86" title="-0.605">script</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.58%); opacity: 0.81" title="0.091">became</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 98.31%); opacity: 0.80" title="0.023">movie</span><span style="opacity: 0.80">! </span><span style="background-color: hsl(120, 100.00%, 96.41%); opacity: 0.81" title="0.068">what</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-2.120">waste</span><span style="opacity: 0.80">! </span><span style="background-color: hsl(0, 100.00%, 98.21%); opacity: 0.80" title="-0.025">how</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.51%); opacity: 0.81" title="0.093">many</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.80%); opacity: 0.82" title="-0.260">original</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.39%); opacity: 0.82" title="-0.236">scripts</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.93%); opacity: 0.81" title="-0.054">are</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.05%); opacity: 0.82" title="-0.174">scattered</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.23%); opacity: 0.82" title="0.204">around</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.32%); opacity: 0.82" title="0.164">without</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.03%); opacity: 0.80" title="0.010">being</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.99%); opacity: 0.81" title="-0.079">produced</span><span style="opacity: 0.80">?   </span><span style="background-color: hsl(0, 100.00%, 98.99%); opacity: 0.80" title="-0.011">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.91%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0 ...

# %% [markdown]
# Посмотрим на примеры неправильной классификации, наконец:

# %%
import numpy as np

preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.090</b>, score <b>-2.312</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.045
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.356
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">i </span><span style="background-color: hsl(0, 100.00%, 95.94%); opacity: 0.81" title="-0.032">really</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 64.56%); opacity: 0.97" title="0.708">liked</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.10%); opacity: 0.80" title="-0.020">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.61%); opacity: 0.82" title="0.090">film</span><span style="opacity: 0.80"> - </span><span style="background-color: hsl(0, 100.00%, 85.29%); opacity: 0.85" title="-0.202">not</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.74%); opacity: 0.81" title="0.059">so</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.00%); opacity: 0.84" title="-0.151">much</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.80%); opacity: 0.81" title="-0.034">for</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.01%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.16%); opacity: 0.81" title="0.041">story</span><span style="opacity: 0.80"> (</span><span style="background-color: hsl(120, 100.00%, 95.98%); opacity: 0.81" title="0.032">which</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.25%); opacity: 0.82" title="-0.066">was</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 71.73%); opacity: 0.92" title="-0.512">okay</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 95.05%); opacity: 0.81" title="-0.043">but</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.25%); opacity: 0.82" title="-0.066">was</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 70.50%); opacity: 0.93" title="0.545">bit</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 66.43%); opacity: 0.96" title="-0.655">slow</span><span style="opacity: 0.80">-</span><span style="background-color: hsl(120, 100.00%, 65.25%); opacity: 0.96" title="0.688">moving</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 98.19%); opacity: 0.80" title="-0.010">in</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.51%); opacity: 0.89" title="0.393">spots</span><span style="opacity: 0.80">) </span><span style="background-color: hsl(0, 100.00%, 95.05%); opacity: 0.81" title="-0.043">but</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.32%); opacity: 0.83" title="-0.145">moreso</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.80%); opacity: 0.81" title="-0.034">for</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.01%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.84%); opacity: 0.82" title="-0.087">incredibly</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 74.63%); opacity: 0.90" title="0.439">beautiful</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.18%); opacity: 0.84" title="-0.147">scenery</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.33%); opacity: 0.82" title="-0.065">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 90.95%); opacity: 0.82" title="-0.101">greece</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.89%); opacity: 0.8 ...

# %% [markdown]
# ## Придумываем новые признаки

# %% [markdown]
# ### Tf-idf
#
# Сейчас мы на все слова смотрим с одинаковым весом - хотя какие-то из них более редкие, какие-то более частые, и эта частотность - полезная, вообще говоря, информация.
#
# Самый простой способ добавить статистическую информацию о частотностях - сделать *tf-idf* взвешивание:
#
# $$\text{tf-idf}(t, d) = \text{tf}(t, d) \times \text{idf}(t)$$
#
# *tf* - term-frequency - частотность слова `t` в конкретном документе `d` (рецензии в нашем случае). Это ровно то, что мы уже считали.
#
# *idf* - inverse document-frequency - коэффициент, который тем больше, чем в меньшем числе документов встречалось данное слово. Считается как-нибудь так:
# $$\text{idf}(t) = \text{log}\frac{1 + n_d}{1 + n_{d(t)}} + 1$$
# где $n_d$ - число всех документов, а $n_{d(t)}$ - число документов со словом `t`.
#
# Использовать его просто - нужно заменить `CountVectorizer` на `TfidfVectorizer`.
#
# **Задание** Попробуйте запустить `TfidfVectorizer`. Посмотрите на ошибки, которые он научился исправлять, и на ошибки, которые он начал делать - по сравнению с `CountVectorizer`.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Test accuracy = 88.29%

# %%
preds2 = model.predict(test_df["review"])

# %%
test_df.head()
# Out:
#    is_positive                                             review
# 0            0  A formulaic story with all the tired cliches. ...
# 1            1  This is both an entertaining and a touching ve...
# 2            0  Corey Haim is never going to be known as one o...
# 3            1  If you believe that any given war movie can ma...
# 4            1  Carla Gugino literally melts the screen in thi...

# %%
inspect_idxs = np.argwhere(preds2 != preds).reshape(-1)

# %%
trues = np.argwhere(preds2 == test_df.is_positive).reshape(-1)
falses = np.argwhere(preds2 != test_df.is_positive).reshape(-1)

# %% [markdown]
# Исправленные ошибки

# %%
improved = set(inspect_idxs).intersection(set(trues))

# %%
i = 150
print(preds[list(improved)[i]])
print(preds2[list(improved)[i]])
print(test_df.is_positive.iloc[list(improved)[i]])
# Out:
# 0
# 1
# 1

# %% [markdown]
# Нафигаченные новые ошибки

# %%
mistakes = set(inspect_idxs).intersection(set(falses))

# %%
i = 150
print(preds[list(mistakes)[i]])
print(preds2[list(mistakes)[i]])
print(test_df.is_positive.iloc[list(mistakes)[i]])
# Out:
# 1
# 0
# 1

# %% [markdown]
# ### N-граммы слов
#
# До сих пор мы смотрели на тексты как на мешок слов - но очевидно, что есть разница между `good movie` и `not good movie`.
#
# Добавим информацию (хоть какую-то) о последовательностях слов - будем извлекать еще и биграммы слов.
#
# В Vectorizer'ах для этого есть параметр `ngram_range=(n_1, n_2)` - он говорит, что нужны n_1-...n_2-граммы.
#
# **Задание** Попробуйте увеличенный range и поинтерпретируйте полученный результат.

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.64%

# %% [markdown]
# ### N-граммы символов
#
# Символьные n-граммы дают простой способ выучить полезные корни и суффиксы, не связываясь с этой вашей лингвистикой - только статистика, только хардкор.
#
# Например, слово `badass` мы можем представить в виде такой последовательности триграмм:
#
# `##b #ba bad ada das ass ss# s##`
#
# So interpretable, неправда ли?
#
# Реализовать это дело всё так же просто - нужно поставить `analyzer='char'` в вашем любимом Vectorizer'е и выбрать размер `ngram_range`.
#
# **Задание** Запилите классификатор на n-граммах символов и визуализируйте его.

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 87.85%

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.962</b>, score <b>3.244</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.195
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.92%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.050
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 94.93%); opacity: 0.81" title="-0.002">t</span><span style="background-color: hsl(120, 100.00%, 98.15%); opacity: 0.80" title="0.000">h</span><span style="background-color: hsl(120, 100.00%, 92.76%); opacity: 0.82" title="0.003">i</span><span style="background-color: hsl(120, 100.00%, 86.81%); opacity: 0.84" title="0.007">s</span><span style="background-color: hsl(120, 100.00%, 81.04%); opacity: 0.87" title="0.011"> </span><span style="background-color: hsl(120, 100.00%, 83.94%); opacity: 0.85" title="0.009">i</span><span style="background-color: hsl(120, 100.00%, 89.71%); opacity: 0.83" title="0.005">s</span><span style="background-color: hsl(120, 100.00%, 92.26%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 92.75%); opacity: 0.82" title="0.003">b</span><span style="background-color: hsl(120, 100.00%, 86.26%); opacity: 0.84" title="0.007">o</span><span style="background-color: hsl(120, 100.00%, 81.77%); opacity: 0.87" title="0.011">t</span><span style="background-color: hsl(120, 100.00%, 81.38%); opacity: 0.87" title="0.011">h</span><span style="background-color: hsl(120, 100.00%, 83.23%); opacity: 0.86" title="0.009"> </span><span style="background-color: hsl(120, 100.00%, 91.76%); opacity: 0.82" title="0.003">a</span><span style="background-color: hsl(120, 100.00%, 89.81%); opacity: 0.83" title="0.005">n</span><span style="background-color: hsl(120, 100.00%, 87.11%); opacity: 0.84" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 82.61%); opacity: 0.86" title="0.010">e</span><span style="background-color: hsl(120, 100.00%, 83.41%); opacity: 0.86" title="0.009">n</span><span style="background-color: hsl(120, 100.00%, 87.89%); opacity: 0.84" title="0.006">t</span><span style="background-color: hsl(120, 100.00%, 83.19%); opacity: 0.86" title="0.009">e</span><span style="background-color: hsl(120, 100.00%, 75.76%); opacity: 0.90" title="0.016">r</span><span style="background-color: hsl(120, 100.00%, 73.20%); opacity: 0.91" title="0.018">t</span><span style="background-color: hsl(120, 100.00%, 76.28%); opacity: 0.89" title="0.015">a</span><span style="background-color: hsl(120, 100.00%, 79.55%); opacity: 0.88" title="0.013">i</span><span style="background-color: hsl(120, 100.00%, 82.18%); opacity: 0.86" title="0.010">n</span><span style="background-color: hsl(120, 100.00%, 88.42%); opacity: 0.83" title="0.006">i</span><span style="background-color: hsl(120, 100.00%, 96.37%); opacity: 0.81" title="0.001">n</span><span style="background-color: hsl(120, 100.00%, 97.00%); opacity: 0.80" title="0.001">g</span><span style="background-color: hsl(120, 100.00%, 92.90%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 86.29%); opacity: 0.84" title="0.007">a</span><span style="background-color: hsl(120, 100.00%, 81.53%); opacity: 0.87" title="0.011">n</span><span style="background-color: hsl(120, 100.00%, 86.24%); opacity: 0.84" title="0.007">d</span><span style="background-color: hsl(120, 100.00%, 94.01%); opacity: 0.81" title="0.002"> </span><span style="background-color: hsl(120, 100.00%, 98.84%); opacity: 0.80" title="0.000">a</span><span style="background-color: hsl(120, 100.00%, 88.19%); opacity: 0.83" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 79.57%); opacity: 0.88" title="0.013">t</span><span style="background-color: hsl(120, 100.00%, 73.75%); opacity: 0.91" title="0.018">o</span><span style="background-color: hsl(120, 100.00%, 73.15%); opacity: 0.91" title="0.018">u</span><span style="background-color: hsl(120, 100.00%, 80.55%); opacity: 0.87" title="0.012">c</span><span style="background-color: hsl(120, 100.00%, 89.32%); opacity: 0.83" title="0.005">h</span><span style="background-color: hsl(0, 100.00%, 90.57%); opacity: 0.83" title="-0.004">i</span><span style="background-color: hsl(0, 100.00%, 87.40%); opacity: 0.84" title="-0.006">n</span><span ...

# %% [markdown]
# ## Подключаем лингвистику

# %% [markdown]
# ### Лемматизация и стемминг
#
# Если присмотреться, можно найти формы одного слова с разной семантической окраской по мнению классификатора. Или нет?
#
# **Задание** Найти формы слова с разной семантической окраской.
#
# Поверя, что они есть, попробуем что-нибудь с этим сделать.
#
# Например, лемматизируем - сведем к начальной форме все слова. Поможет в этом библиотека spacy.

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en', disable=['parser'])

docs = [doc for doc in nlp.pipe(train_df.review.values[:50])]

# %%
for token in docs[0]:
    print(token.text, token.lemma_, token.ent_type_)
# Out:
# Dreamgirls dreamgirl
# , ,
# despite despite
# its -PRON-
# fistful fistful
# of of
# Tony tony PERSON
# wins win
# in in
# an an DATE
# incredibly incredibly DATE
# weak weak DATE
# year year DATE
# on on
# Broadway broadway FAC
# , ,
# has have
# never never
# been be
# what what
# one one
# would would
# call call
# a a
# jewel jewel
# in in
# the the
# crown crown
# of of
# stage stage
# musicals musical
# . .
# However however
# , ,
# that that
# is be
# not not
# to to
# say say
# that that
# in in
# the the
# right right
# cinematic cinematic
# hands hand
# it -PRON-
# could could
# not not
# be be
# fleshed flesh
# out out
# and and
# polished polish
# into into
# something something
# worthwhile worthwhile
# on on
# - -
# screen screen
# . .
# Unfortunately unfortunately
# , ,
# what what
# transfers transfer
# to to
# the the
# screen screen
# is be
# basically basically
# a a
# slavishly slavishly
# faithful faithful
# version version
# of of
# the the
# stage stage
# hit hit
# with with
# all all
# of of
# its -PRON-
# inherent inherent
# weaknesses weakness
# intact intact
# . .
# First first ORDINAL
# , ,
# the the
# score score
# has have
# never never
# been be
# one one CARDINAL
# of of
# the the
# strong strong
# points point
# of of
# this this
# production production
# and and
# the the
# film film
# does do
# not not
# change change
# that that
# factor factor
# . .
# There there
# are be
# lots lot
# of of
# songs song
# ( (
# perhaps perhaps
# too too
# many many
# ? ?
# ) )
# , ,
# but but
# few few
# of of
# them -PRON-
# are be
# especially especially
# memorable memorable
# . .
# The the
# closest close
# any any
# come come
# to to
# catchy catchy
# tunes tune
# are be
# the the
# title title
# song song
# and and
# One one TIME
# Night night TIME
# Only only
# - -
# the the
# much much
# acclaimed acclaimed
# And and
# I -PRON-
# Am be
# Telling tell
# You -PRON-
# That that
# I -PRON-
# Am be
# Not not
# Going go
# is be
# less less
# a a
# great great
# song song
# than than
# it -PRON-
# is be
# a a
# dramatic dramatic
# set set
# piece piece
# for for
# the the
# character character
# of of
# Effie effie PERSON
# ( (
# Jennifer jennifer PERSON
# Hudson hudson PERSON
# ) )
# . .
# The the
# film film
# is be
# slick slick
# and and
# technically technically
# well well
# - -
# produced produce
# , ,
# but but
# the the
# story story
# and and
# characters character
# are be
# surprisingly surprisingly
# thin thin
# and and
# lacking lacking
# in in
# any any
# resonance resonance
# . .
# There there
# is be
# some some
# interest interest
# in in
# the the
# opening opening
# moments moment
# , ,
# watching watch
# Jamie jamie PERSON
# Foxx foxx PERSON
# 's 's PERSON
# Svengali svengali ORG
# - -
# like like
# manager manager
# manipulate manipulate
# his -PRON-
# acts act
# to to
# the the
# top top
# , ,
# but but
# that that
# takes take
# a a
# back back
# seat seat
# in in
# the the
# latter latter
# portion portion
# of of
# the the
# film film
# , ,
# when when
# the the
# story story
# conveniently conveniently
# tries try
# to to
# cast cast
# him -PRON-
# as as
# a a
# villain villain
# , ,
# despite despite
# his -PRON-
# having have
# been be
# right right
# from from
# a a
# business business
# stand stand
# - -
# point point
# for for
# a a
# good good
# majority majority
# of of
# the the
# film film
# . .
# Beyonce beyonce PERSON
# Knowles knowles PERSON
# is be
# lovely lovely
# and and
# sings sing
# her -PRON-
# songs song
# perfectly perfectly
# well well
# , ,
# but but
# is be
# stuck stick
# with with
# a a
# character character
# who who
# is be
# basically basically
# all all
# surface surface
# glitz glitz
# . .
# Anika anika PERSON
# Noni noni PERSON
# Rose rose PERSON
# as as
# the the
# third third ORDINAL
# member member
# of of
# the the
# Dreamgirls dreamgirls GPE
# trio trio
# literally literally
# has have
# nothing nothing
# to to
# do do
# for for
# the the
# entire entire
# film film
# . .
# Eddie eddie PERSON
# Murphy murphy PERSON
# acquits acquit
# himself -PRON-
# well well
# as as
# a a
# singer singer
# obviously obviously
# based base
# on on
# James james PERSON
# Brown brown PERSON
# , ,
# but but
# the the
# role role
# is be
# not not
# especially especially
# meaty meaty
# and and
# ultimately ultimately
# has have
# little little
# impact impact
# . .
# Foxx foxx GPE
# would would
# seem seem
# ideal ideal
# casting casting
# , ,
# but but
# he -PRON-
# seems seem
# oddly oddly
# withdrawn withdraw
# and and
# bored bored
# . .
# The the
# film film
# 's 's
# biggest big
# selling selling
# point point
# is be
# surely surely
# former former
# American american ORG
# Idol idol ORG
# contestant contestant
# / /
# Oscar oscar PERSON
# winner winner
# Jennifer jennifer PERSON
# Hudson hudson PERSON
# in in
# the the
# central central
# role role
# of of
# Effie effie PERSON
# White white PERSON
# , ,
# the the
# temperamental temperamental
# singer singer
# who who
# gets get
# booted boot
# from from
# the the
# group group
# and and
# makes make
# a a
# triumphant triumphant
# closing closing
# act act
# return return
# . .
# For for
# me -PRON-
# , ,
# Effie effie PERSON
# has have
# always always
# been be
# a a
# big big
# problem problem
# in in
# both both
# the the
# show show
# and and
# the the
# movie movie
# . .
# The the
# film film
# obviously obviously
# wants want
# you -PRON-
# to to
# feel feel
# sorry sorry
# for for
# her -PRON-
# and and
# rather rather
# ham ham
# - -
# handedly handedly
# takes take
# her -PRON-
# side side
# , ,
# but but
# I -PRON-
# have have
# never never
# been be
# sure sure
# that that
# this this
# character character
# deserves deserve
# that that
# kind kind
# of of
# devotion devotion
# . .
# From from
# the the
# start start
# , ,
# Effie effie PERSON
# conducts conduct
# herself -PRON-
# for for
# the the
# most most
# part part
# like like
# an an
# obnoxious obnoxious
# , ,
# egotistical egotistical
# , ,
# self self
# - -
# centered center
# diva diva
# , ,
# who who
# is be
# more more
# interested interested
# in in
# what what
# everyone everyone
# else else
# can can
# do do
# for for
# her -PRON-
# rather rather
# than than
# having have
# much much
# vested vested
# interest interest
# in in
# the the
# group group
# of of
# which which
# she -PRON-
# is be
# a a
# part part
# . .
# When when
# she -PRON-
# is be
# booted boot
# from from
# the the
# group group
# for for
# her -PRON-
# unprofessionalism unprofessionalism
# and and
# bad bad
# attitude attitude
# , ,
# the the
# charges charge
# are be
# more more
# than than
# well well
# - -
# founded found
# , ,
# but but
# the the
# stage stage
# show show
# / /
# film film
# seem seem
# to to
# think think
# Effie effie PERSON
# should should
# be be
# cut cut
# unlimited unlimited
# slack slack
# simply simply
# because because
# she -PRON-
# has have
# a a
# great great
# voice voice
# . .
# Even even
# though though
# the the
# film film
# tries try
# to to
# soften soften
# some some
# of of
# Effie effie PERSON
# 's 's
# harder hard
# edges edge
# to to
# make make
# her -PRON-
# more more
# likable likable
# , ,
# the the
# charges charge
# still still
# stand stand
# . .
# Her -PRON-
# story story
# becomes become
# more more
# manipulative manipulative
# by by
# suggesting suggest
# she -PRON-
# should should
# have have
# our -PRON-
# further further
# sympathy sympathy
# because because
# she -PRON-
# is be
# an an
# unwed unwed
# mother mother
# struggling struggle
# to to
# raise raise
# her -PRON-
# daughter daughter
# - -
# using use
# the the
# implication implication
# that that
# ( (
# much much
# like like
# the the
# talent talent
# card card
# ) )
# motherhood motherhood
# immediately immediately
# makes make
# any any
# behavior behavior
# excusable excusable
# . .
# Indeed indeed
# the the
# only only
# big big
# effort effort
# the the
# film film
# makes make
# to to
# show show
# Effie effie PERSON
# 's 's
# mothering mothering
# is be
# to to
# tell tell
# us -PRON-
# about about
# it -PRON-
# and and
# then then
# include include
# a a
# scene scene
# where where
# she -PRON-
# barks bark
# at at
# her -PRON-
# daughter daughter
# in in
# the the
# unemployment unemployment
# office office
# , ,
# insists insist
# that that
# the the
# girl girl
# has have
# " "
# no no
# father father
# " "
# and and
# then then
# refuse refuse
# to to
# look look
# for for
# gainful gainful
# employment employment
# to to
# support support
# them -PRON-
# since since
# singing sing
# is be
# all all
# she -PRON-
# knows know
# . .
# In in
# the the
# hands hand
# of of
# a a
# skillful skillful
# actress actress
# , ,
# the the
# gaps gap
# could could
# perhaps perhaps
# have have
# been be
# remedied remedi
# with with
# technique technique
# and and
# charisma charisma
# . .
# Unfortunately unfortunately
# , ,
# Hudson hudson LOC
# is be
# not not
# that that
# actress actress
# . .
# She -PRON-
# sings sing
# well well
# , ,
# but but
# the the
# dialog dialog
# - -
# driven drive
# moments moment
# do do
# not not
# come come
# naturally naturally
# to to
# her -PRON-
# nor nor
# do do
# high high
# emotional emotional
# moments moment
# . .
# Effie effie PERSON
# 's 's
# signature signature
# moment moment
# ( (
# the the
# aforementioned aforementioned
# And and
# I -PRON-
# Am be
# Telling tell
# You -PRON-
# ... ...
# number number
# ) )
# is be
# well well
# - -
# sung sing
# by by
# Hudson hudson PERSON
# , ,
# but but
# emotionally emotionally
# flat flat
# in in
# the the
# acting acting
# department department
# . .
# Effie effie PERSON
# is be
# supposed suppose
# to to
# expressing express
# her -PRON-
# rage rage
# and and
# desperation desperation
# at at
# her -PRON-
# predicament predicament
# , ,
# but but
# Hudson hudson PERSON
# comes come
# off off
# as as
# a a
# cabaret cabaret
# performer performer
# belting belt
# out out
# a a
# hot hot
# number number
# . .
# All all
# in in
# all all
# , ,
# not not
# quite quite
# the the
# emotional emotional
# highlight highlight
# one one
# expects expect
# . .
# The the
# latter latter
# portion portion
# of of
# the the
# film film
# is be
# basically basically
# a a
# predictable predictable
# melange melange
# of of
# events event
# that that
# maneuver maneuver
# Foxx foxx GPE
# into into
# Hudson hudson ORG
# 's 's
# earlier early
# position position
# and and
# allow allow
# her -PRON-
# to to
# strut strut
# back back
# in in
# and and
# lord lord
# it -PRON-
# over over
# everyone everyone
# . .
# Foxx foxx GPE
# 's 's
# criminal criminal
# offenses offense
# in in
# the the
# film film
# are be
# undoubtedly undoubtedly
# par par
# for for
# the the
# course course
# of of
# many many
# struggling struggle
# record record
# producers producer
# , ,
# but but
# the the
# film film
# 's 's
# seeming seem
# implication implication
# that that
# he -PRON-
# has have
# it -PRON-
# coming come
# because because
# he -PRON-
# helped help
# usher usher
# in in
# the the
# disco disco
# era era
# is be
# rather rather
# ridiculous ridiculous
# , ,
# not not
# to to
# mention mention
# pretentious pretentious
# and and
# condescending condescend
# , ,
# particularly particularly
# coming come
# from from
# a a
# film film
# with with
# all all
# of of
# the the
# depth depth
# of of
# a a
# puddle puddle
# . .
# The the
# end end
# result result
# is be
# a a
# faithful faithful
# rendition rendition
# of of
# the the
# stage stage
# hit hit
# , ,
# drained drain
# of of
# emotion emotion
# , ,
# energy energy
# or or
# anything anything
# that that
# can can
# be be
# described describe
# as as
# dynamic dynamic
# . .

# %%
docs[0][3].ent_type_
# Out:
# ''

# %% [markdown]
# Весь этот процесс очень долгий, поэтому я предподсчитал всё.

# %%
import pickle
from tqdm import tqdm

# with open('train_docs.pkl', 'rb') as f:
#     train_docs = pickle.load(f)
    
# with open('test_docs.pkl', 'rb') as f:
#     test_docs = pickle.load(f)
train_docs = [doc for doc in tqdm(nlp.pipe(train_df.review.values), total = len(train_df))]
# Out:
# 100%|██████████| 25000/25000 [08:46<00:00, 47.50it/s]

# %%
test_docs = [doc for doc in tqdm(nlp.pipe(train_df.review.values), total = len(train_df))]
# Out:
# 100%|██████████| 25000/25000 [08:38<00:00, 48.17it/s]

# %%
from nltk.tokenize import WordPunctTokenizer

# %%
tokeniser = WordPunctTokenizer()

# %%
tokens = tokeniser.tokenize(train_df.review.iloc[0])

# %%
train_lemmas = [[x.lemma_ for x in doc if x.lemma_!= "-PRON-"] for doc in train_docs]
test_lemmas = [[x.lemma_ for x in doc if x.lemma_ != "-PRON-"] for doc in test_docs]

# %% [markdown]
# **Задание** Сделайте классификатор на лемматизированных текстах.

# %%
vectorizer = TfidfVectorizer(
    analyzer='word',
    tokenizer = lambda x: x,
    preprocessor = lambda x: x,
    token_pattern = None) #<- for already tokenized text

classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_lemmas, train_df.is_positive)
# Out:
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#      steps=[('vectorizer', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2',
#         preprocessor=<function...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
preds = model.predict(test_lemmas)
print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
# Out:
# Test accuracy = 49.99%

# %% [markdown]
# Более простой способ нормализации слов - использовать стемминг. Он немного тупой, не учитывает контекст, но иногда оказывается даже эффективнее лемматизации - а, главное, быстрее.
#
# По сути это просто набор правил, как обрезать слово, чтобы получить основу (stem):

# %%
from nltk import PorterStemmer

stemmer = PorterStemmer()

print(stemmer.stem('become'))
print(stemmer.stem('Becomes'))
print(stemmer.stem('became'))
# Out:
# becom
# becom
# becam

# %% [markdown]
# **Задание** Попробуйте вместо лемм классифицировать основы.

# %%
train_stems = [stemmer.stem(x) for x in train_df.review.values]
test_stems = [stemmer.stem(x) for x in test_df.review.values]

# %%
vectorizer = TfidfVectorizer(ngram_range= (3,3))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_stems, train_df.is_positive)
# Out:
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#      steps=[('vectorizer', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(3, 3), norm='l2', preprocessor=None, smooth_idf=...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
preds = model.predict(test_stems)
print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
# Out:
# Test accuracy = 83.71%

# %% [markdown]
# ### NER
#
# В текстах рецензий очень много именованных сущностей. Вот, например:

# %%
displacy.render(docs[0], style='ent', jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">Dreamgirls, despite its fistful of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wins in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     an incredibly weak year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the score has never been
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     One Night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jamie Foxx's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Svengali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Beyonce Knowles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Anika Noni Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  member of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  trio literally has nothing to do for the entire film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Eddie Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  acquits himself well as a singer obviously based on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     James Brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , but the role is not especially meaty and ultimately has little impact.
# <

# %% [markdown]
# Вообще говоря, почему вдруг какой-нибудь Депп должен нести семантическую окраску? Однако оказывается, что классификатор выучивает, что какие-то имена чаще в положительных рецензиях - или наоборот. Это похоже на переобучение - почему бы не попробовать вырезать сущности?
#
# **Задание** Удалите из текстов какие-то из сущностей, пользуясь координатами из запикленных файлов. Описание сущностей можно посмотреть [здесь](https://spacy.io/api/annotation#named-entities). Запустите классификатор.

# %%
train_stems = [[stemmer.stem(x.text) for x in doc if x.ent_type != "PERSON"] for doc in train_docs]
test_stems = [[stemmer.stem(x.text) for x in doc if x.ent_type != "PERSON"] for doc in test_docs]

# %%
vectorizer = TfidfVectorizer(
    analyzer='word',
    tokenizer = lambda x: x,
    preprocessor = lambda x: x,
    token_pattern = None) #<- for already tokenized text

classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_stems, train_df.is_positive)
# Out:
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#      steps=[('vectorizer', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2',
#         preprocessor=<function...penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
preds = model.predict(test_stems)
print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
# Out:
# Test accuracy = 50.06%

# %% [markdown]
# ## Включаем дип лёрнинг

# %% [markdown]
# Мы тут пришли deep learning'ом заниматься, а делаем почему-то модель на логистической регрессии. Как так?
#
# Попробуем запустить относительно стандартную модель для классификации текстов - сверточная сеть поверх словных эмбеддингов.
#
# Разбираться, что это за зверь, будем на следующих занятиях, а пока будем просто им пользоваться :)
#
# Каждое предложение нужно представлять набором слов - и сразу же начинаются проблемы. Во-первых, как ограничить длину предложения?
#
# Прикинем по гистограмме, какая длина нам подходит:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

_, _, hist = plt.hist(train_df.review.apply(lambda text: len(text)), bins='auto')
hist
# Out:
# <a list of 223 Patch objects>

# %% [markdown]
# Кроме этого, нужно перенумеровать как-то слова.

# %%
from collections import Counter

words_counter = Counter((word for text in train_df.review for word in text.lower().split()))

word2idx = {
    '': 0,
    '<unk>': 1
}
for word, count in words_counter.most_common():
    if count < 19:
        break
        
    word2idx[word] = len(word2idx)
    
print('Words count', len(word2idx))
# Out:
# Words count 16447

# %% [markdown]
# **Задание** Сконвертируйте данные

# %%
def convert(texts, word2idx, max_text_len):
    data = np.zeros((len(texts), max_text_len), dtype=np.int)
    
    for i, text in enumerate(texts):
        for j, word in enumerate(text.lower().split()):
            if j >= max_text_len:
                break
            data[i,j] = word2idx.get(word, 1)
    return data

X_train = convert(train_df.review, word2idx, 100)
X_test = convert(test_df.review, word2idx, 100)

# %% [markdown]
# Поставим учиться модельку на keras.
#
# *Напоминание*: на keras, чтобы обучить модель, нужно
# 1. Определить модель, например:
# ```python
# model = Sequential()
# model.add(Dense(1, activation='sigmoid', input_dim=NUM_WORDS))
# ```
# 2. Задать функцию потерь и оптимизатор:
# ```python
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ```
#
# 3. Запустить обучение:
# ```python
# model.fit(X_train, y_train,
#           batch_size=32,
#           epochs=3,
#           validation_data=(X_test, y_test))
# ```
#
# В NLP чаще всего ставятся задачи классификации, поэтому нужно запомнить такие функции потерь:
#
# *   **categorical_crossentropy** - для многоклассовой классификации, в качестве меток должны передаваться one-hot-encoding вектора
# *   **sparse_categorical_crossentropy** - аналогично предыдущему, но в качестве меток нужно передавать просто индексы соответствующих классов
# *   **binary_crossentropy** - для бинарной классификации
#
#
# В качестве оптимизатора обычно используют `sgd` или `adam`.

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, Conv1D, GlobalMaxPooling1D, Dropout

model = Sequential([
    Embedding(input_dim=len(word2idx), output_dim=64, input_shape=(X_train.shape[1],)),
    Conv1D(filters=128, kernel_size=3, padding='valid', activation='relu', strides=1),
    GlobalMaxPooling1D(),
    Dense(units=1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 64)           1052608
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 98, 128)           24704
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,077,441
# Trainable params: 1,077,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, train_df.is_positive, batch_size=128, epochs=10, 
          validation_data=(X_test, test_df.is_positive))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
#  4736/25000 [====>.........................] - ETA: 5:46 - loss: 0.6900 - acc: 0.5372
# /home/alexander/miniconda3/envs/temp3/lib/python3.6/site-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.234344). Check your callbacks.
#   % delta_t_median)
# 25000/25000 [==============================] - 85s 3ms/step - loss: 0.5898 - acc: 0.6884 - val_loss: 0.4667 - val_acc: 0.7741
# Epoch 2/10
# 25000/25000 [==============================] - 3s 117us/step - loss: 0.3844 - acc: 0.8308 - val_loss: 0.4315 - val_acc: 0.7979
# Epoch 3/10
# 25000/25000 [==============================] - 1s 39us/step - loss: 0.2516 - acc: 0.9010 - val_loss: 0.4433 - val_acc: 0.8056
# Epoch 4/10
# 25000/25000 [==============================] - 1s 40us/step - loss: 0.1474 - acc: 0.9492 - val_loss: 0.5153 - val_acc: 0.7940
# Epoch 5/10
# 25000/25000 [==============================] - 1s 46us/step - loss: 0.0735 - acc: 0.9809 - val_loss: 0.6052 - val_acc: 0.7901
# Epoch 6/10
# 25000/25000 [==============================] - 1s 41us/step - loss: 0.0327 - acc: 0.9949 - val_loss: 0.6929 - val_acc: 0.7899
# Epoch 7/10
# 25000/25000 [==============================] - 1s 43us/step - loss: 0.0138 - acc: 0.9989 - val_loss: 0.7743 - val_acc: 0.7872
# Epoch 8/10
# 25000/25000 [==============================] - 1s 40us/step - loss: 0.0063 - acc: 0.9998 - val_loss: 0.8397 - val_acc: 0.7866
# Epoch 9/10
# 25000/25000 [==============================] - 1s 44us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.8938 - val_acc: 0.7846
# Epoch 10/10
# 25000/25000 [==============================] - 1s 46us/step - loss: 0.0022 - acc: 1.0000 - val_loss: 0.9382 - val_acc: 0.7832

# %% [markdown]
# **Задание** Подсчитайте качество модели на тесте

# %%
from sklearn.metrics import accuracy_score

# %%
preds = model.predict_proba(X_test)

# %%
accuracy_score(test_df.is_positive, preds > 0.5)
# Out:
# 0.78316

# %% [markdown]
# ## Немного математики
#
# Вспомним, как работает логистическая регрессия, которой мы тут столько пользовались.
#
# Пригодятся:

# %%
np.random.seed(42)
w, X, y = np.random.random(10), np.random.random((11, 10)), 2 * (np.random.randint(0, 2, 11) - 0.5)

# %% [markdown]
# Это обычная линейная функция
#
# $$h_w(X) = \sigma(X w),$$
# $$\sigma(z) = \frac{1}{1 + e^{-z}}$$
#
# Подсчитайте ее:

# %%
def forward(X, w):
    x = np.multiply(X, w)
    return 1/(1+ np.exp(-x))

# %% [markdown]
# Функция потерь
# $$J(w)  = \frac{1}{m} \left(-y^T \text{log}(h_w) - (1-y)^T \text{log}(1 - h_w)\right)$$
#
# Для оптимизации с SGD нужно считать градиент по функции потерь
# $\frac{\partial J(w)}{\partial w}$.
#
# **Задание** Подсчитайте их.

# %%
def loss(X, w, y):
    """ Функция потерь
    X - матрица (n, m)
    w - вектор (m,)
    y - вектор (n,)
    """
    <calc loss>


def gradient(X, w, y):
    """ Градиент функции потерь по w
    X - матрица (n, m)
    w - вектор (m,)
    y - вектор (n,)
    """
    <calc grad>


print('loss = ', loss(X, w, y))
print('gradient = ', gradient(X, w, y))

assert gradient(X, w, y).shape == w.shape

# %% [markdown]
# Очень часто при подсчёте градиента допускаются ошибки, проверьте правильность реализации подсчёта градиента с помощью конечных разностей:
#
# $$[\nabla f(x)]_i \approx \frac{f(x + \varepsilon \cdot e_i) - f(x)}{\varepsilon}$$
#
# где $e_i = (0, ... , 0, 1, 0, ..., 0)$ - i-й базисный орт, $\varepsilon \approx 10^{-8}$

# %%
def grad_finite_diff(func, x, eps=1e-8):
    """
    w - вектор (m,)
    func - скалярная функция от векторного аргумента w, func(w) = число
    eps - константа для проверки градиента
    """
    x, fval, dnum = x.astype(np.float64), func(x), np.zeros_like(x)
    
    E = np.eye(x.shape[0])
    deltas = np.array([func(x + eps * E[i]) for i in range(x.shape[0])])
    return (deltas - fval) / eps

mat_grad = gradient(X, w, y)
num_grad = grad_finite_diff(lambda w: loss(X, w, y), w)

err = np.max(np.abs(mat_grad - num_grad))
print('err = ', err, 'ok' if err < 1e-6 else 'ошибка очень большая =(')

# %% [markdown]
# В итоге получим такой класс:

# %%
class LogisticRegression:
    def __init__(self, lr=0.01, num_iter=100000, fit_intercept=True):
        self.lr = lr
        self.num_iter = num_iter
        self.fit_intercept = fit_intercept
    
    def __add_intercept(self, X):
        intercept = np.ones((X.shape[0], 1))
        return np.concatenate((intercept, X), axis=1)
        
    def fit(self, X, y):
        if self.fit_intercept:
            X = self.__add_intercept(X)
        
        self._w = np.zeros(X.shape[1])
        
        for i in range(self.num_iter):
            grad = gradient(X, self._w, y)
            self._w -= self.lr * grad
    
    def predict_prob(self, X):
        if self.fit_intercept:
            X = self.__add_intercept(X)
    
        return forward(X, self._w)
    
    def predict(self, X, threshold):
        return self.predict_prob(X) >= threshold

# %% [markdown]
# Посмотрим, как всё работает на простых датасетах:

# %%
from sklearn.datasets import make_moons, load_iris

iris = load_iris()
X = iris.data[:, :2]
y = (iris.target != 0) * 1

model = LogisticRegression(lr=0.1, num_iter=300000)
model.fit(X, y)

plt.figure(figsize=(10, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='b', label='0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='r', label='1')
plt.legend()

x1_min, x1_max = X[:,0].min(), X[:,0].max(),
x2_min, x2_max = X[:,1].min(), X[:,1].max(),
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))
grid = np.c_[xx1.ravel(), xx2.ravel()]
probs = model.predict_prob(grid).reshape(xx1.shape)
plt.contour(xx1, xx2, probs, [0.5], linewidths=1, colors='black')

# %%
X, y = make_moons(noise=0.1)

model = LogisticRegression()
model.fit(X, y)

plt.figure(figsize=(10, 6))
plt.scatter(X[y == 0][:, 0], X[y == 0][:, 1], color='b', label='0')
plt.scatter(X[y == 1][:, 0], X[y == 1][:, 1], color='r', label='1')
plt.legend()

x1_min, x1_max = X[:,0].min(), X[:,0].max()
x2_min, x2_max = X[:,1].min(), X[:,1].max()
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))

grid = np.c_[xx1.ravel(), xx2.ravel()]

probs = model.predict_prob(grid).reshape(xx1.shape)
plt.contour(xx1, xx2, probs, [0.5], linewidths=1, colors='black')

# %% [markdown]
# # Сдача задания
#
# Сдаем через [форму](https://goo.gl/forms/TWl14R42ddDPvZLU2).
#
# И можно заполнить [анонимный опрос](https://goo.gl/forms/RII9cRcwoaJjPr2G3).
